# %% [markdown]
# <img src="./Images/hack.png" alt="HackThon" height="1000" width="1000"/>
#
# ## *Test case* : _Image to Text and Text to speech conversion_
#
# ![A robot identifying fruit](./Images/ocr.jpg)

# %%
#!pip install pytesseract
#!pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\program files\anaconda\lib\site-packages (3.0.0)
# Requirement already satisfied: httpx==0.13.3 in c:\program files\anaconda\lib\site-packages (from googletrans) (0.13.3)
# Requirement already satisfied: chardet==3.* in c:\program files\anaconda\lib\site-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\program files\anaconda\lib\site-packages (from httpx==0.13.3->googletrans) (1.5.0)
# Requirement already satisfied: idna==2.* in c:\program files\anaconda\lib\site-packages (from httpx==0.13.3->googletrans) (2.10)
# Requirement already satisfied: hstspreload in c:\program files\anaconda\lib\site-packages (from httpx==0.13.3->googletrans) (2021.12.1)
# Requirement already satisfied: certifi in c:\program files\anaconda\lib\site-packages (from httpx==0.13.3->googletrans) (2021.10.8)
# Requirement already satisfied: sniffio in c:\program files\anaconda\lib\site-packages (from httpx==0.13.3->googletrans) (1.2.0)
# Requirement already satisfied: httpcore==0.9.* in c:\program files\anaconda\lib\site-packages (from httpx==0.13.3->googletrans) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\program files\anaconda\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\program files\anaconda\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (3.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\program files\anaconda\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (3.0.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\program files\anaconda\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (5.2.0)

# %%
from gtts import gTTS
import pytesseract as tess
from PIL import Image
import matplotlib.pyplot as plt
#from googletrans import Translator
import os

# %%
tess.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img = Image.open('I2T2S_2.png')
test = tess.image_to_string(img)

# %%
plt.imshow(img)

# %%
test
# Out:
# '“Sometimes you\nwill never know\nthe VALUE ofa\n\nmoment, until it\n\nbecomes a\nMEMORY.”\n\nDR. SEUSS\n'

# %%
myobj = gTTS(text=test, lang='en', slow=False)
myobj.save('output1.mp3')
#os.system('mpg321 output1.mp3')
os.system('output1.mp3')
print("------ Done -------")
# Out:
# ------ Done -------

# %%
with open('abc.txt',mode ='w') as file:     
      
                 file.write(test)
                 print(test)
# Out:
# “Sometimes you
# will never know
# the VALUE ofa
#
# moment, until it
#
# becomes a
# MEMORY.”
#
# DR. SEUSS
